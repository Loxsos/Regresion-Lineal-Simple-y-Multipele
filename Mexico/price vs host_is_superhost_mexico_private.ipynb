# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# 3  Is the best ever place triple L <br />Location...
# 4                                     No description
#
#                                neighborhood_overview host_name  ...  \
# 0                           No neighborhood_overview  Fernando  ...
# 1                           No neighborhood_overview  Nicholas  ...
# 2  Coyoacan is a beautiful neighborhood famous fo...    Trisha  ...
# 3  Is located in the best area of Mexico City, Po...    Andrea  ...
# 4                           No neighborhood_overview  Fernando  ...
#
#   number_of_reviews_ltm number_of_reviews_l30d review_scores_rating  \
# 0                   0.0                    0.0                 4.58
# 1                   4.0                    0.0                 4.90
# 2                   7.0                    2.0                 4.91
# 3                   0.0                    0.0                 4.91
# 4                   0.0                    0.0                 4.80
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.56                      4.70                  4.87
# 1                   4.81                      4.75                  4.94
# 2                   4.90                      4.96                  4.96
# 3                   5.00                      5.00                  5.00
# 4                   4.80                      4.80                  4.90
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.78                   4.98                4.48
# 1                        4.92                   4.98                4.91
# 2                        4.98                   4.96                4.92
# 3                        4.73                   4.91                4.82
# 4                        4.90                   4.90                4.80
#
#   reviews_per_month
# 0              0.41
# 1              0.31
# 2              0.83
# 3              0.11
# 4              1.17
#
# [5 rows x 49 columns]

# %%
df = df[df['room_type'] == 'Private room']

# %%
df['host_is_superhost'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 17362 entries, 0 to 26580
# Series name: host_is_superhost
# Non-Null Count  Dtype
# --------------  -----
# 17362 non-null  object
# dtypes: object(1)
# memory usage: 271.3+ KB

# %%
df['price'] = df['price'].astype(float)

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_53952\1234139552.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='price', x='host_is_superhost',  color = 'blue', data=df)
plt.title('Price vs Host Is Superhost')
plt.xlabel('Host Is Superhost')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_53952\3302511951.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['host_is_superhost']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-76.16095367]]),
#  'rank_': 1,
#  'singular_': array([41.3199701]),
#  'intercept_': array([770.6611679])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-76.16095367]]
# Intercepto: [770.6611679]
# y = [-76.16095367]x + [770.6611679]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.004940237298714845

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('Host_Is_Superhost vs Price')
plt.xlabel('Host_Is_SuperHost')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['host_is_superhost']])
yPred
# Out:
# array([[770.6611679 ],
#        [694.50021422],
#        [694.50021422],
#        ...,
#        [770.6611679 ],
#        [770.6611679 ],
#        [770.6611679 ]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#     Unnamed: 0       id   host_id  beds  bedrooms           source  \
# 4            5   131610    647454     1         2  previous scrape
# 6            7   171109    816295     1         1      city scrape
# 9           10  1013504   1664327     1         1      city scrape
# 10          11  1051636  22366411     1         1      city scrape
# 11          12  1066945   5870021     1         1      city scrape
#
#                                        name  \
# 4                            MARIA DEL ALMA
# 6           Cool room near WTC and Metrobus
# 9           OASIS IN COYOACAN, SHARED HOUSE
# 10  Chilango chic: room historic Condesa DF
# 11       Villa Alfonsina, Heart of Coyoacan
#
#                                           description  \
# 4                                      No description
# 6   Stay in a private room 2 blocks away from WTC,...
# 9   Private room (single bed) with private  bathro...
# 10  Like home! Private room in charming, tasteful ...
# 11  In front of the Frida Kahlo Museum.<br /> Priv...
#
#                                 neighborhood_overview host_name  ...  \
# 4                            No neighborhood_overview  Fernando  ...
# 6   Great location, feel comfortable and secure at...    Carlos  ...
# 9   Her It's very safe, there are some restaurants...   Edoardo  ...
# 10  In the heart of the real Condesa! Chic yet sti...  Citlalli  ...
# 11  Our street "Allende" is privileged as it is on...    Héctor  ...
#
#    number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 4                     0.0                 4.80                   4.80
# 6                     0.0                 4.84                   4.87
# 9                     1.0                 4.96                   4.90
# 10                    0.0                 4.83                   4.60
# 11                    0.0                 4.93                   4.94
#
#    review_scores_cleanliness review_scores_checkin  \
# 4                       4.80                  4.90
# 6                       4.61                  4.98
# 9                       4.92                  4.92
# 10                      4.97                  4.97
# 11                      4.97                  4.96
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 4                         4.90                    4.90                4.80
# 6                         4.95                    4.97                4.81
# 9                         4.94                    4.92                4.89
# 10                        4.77                    4.93                4.73
# 11                        4.91                    4.97                4.94
#
#    reviews_per_month Predicciones
# 4               1.17   770.661168
# 6               0.84   694.500214
# 9               0.54   694.500214
# 10              0.22   770.661168
# 11              1.15   770.661168
#
# [5 rows x 50 columns]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='price', y='host_is_superhost', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('Host Is Superhost')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.004940237298714845

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.07028682165751161
