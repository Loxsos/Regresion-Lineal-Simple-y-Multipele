# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# 3  Is the best ever place triple L <br />Location...
# 4                                     No description
#
#                                neighborhood_overview host_name  ...  \
# 0                           No neighborhood_overview  Fernando  ...
# 1                           No neighborhood_overview  Nicholas  ...
# 2  Coyoacan is a beautiful neighborhood famous fo...    Trisha  ...
# 3  Is located in the best area of Mexico City, Po...    Andrea  ...
# 4                           No neighborhood_overview  Fernando  ...
#
#   number_of_reviews_ltm number_of_reviews_l30d review_scores_rating  \
# 0                   0.0                    0.0                 4.58
# 1                   4.0                    0.0                 4.90
# 2                   7.0                    2.0                 4.91
# 3                   0.0                    0.0                 4.91
# 4                   0.0                    0.0                 4.80
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.56                      4.70                  4.87
# 1                   4.81                      4.75                  4.94
# 2                   4.90                      4.96                  4.96
# 3                   5.00                      5.00                  5.00
# 4                   4.80                      4.80                  4.90
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.78                   4.98                4.48
# 1                        4.92                   4.98                4.91
# 2                        4.98                   4.96                4.92
# 3                        4.73                   4.91                4.82
# 4                        4.90                   4.90                4.80
#
#   reviews_per_month
# 0              0.41
# 1              0.31
# 2              0.83
# 3              0.11
# 4              1.17
#
# [5 rows x 49 columns]

# %%
df = df[df['room_type'] == 'Entire home/apt']

# %%
df['bathrooms_text'].head(10)
# Out:
# 0     5.5
# 1     1.0
# 2     1.0
# 3     1.5
# 5     5.0
# 7     2.5
# 8     4.5
# 13    3.5
# 16    1.5
# 17    1.0
# Name: bathrooms_text, dtype: float64

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' baths', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('Half-bath', '', regex=False)

# %%
df['bathrooms_text'] = pd.to_numeric(df['bathrooms_text'], errors='coerce')

# %%
df['bathrooms_text'] = df['bathrooms_text'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(x='accommodates', y='bathrooms_text',  color = 'blue', data=df)
plt.title('Accommodates vs bathrooms_text')
plt.xlabel('bathrooms_text')
plt.ylabel('accommodates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_34888\1718685436.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['bathrooms_text']]
dep = df[['accommodates']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
df = df.dropna(subset=['bathrooms_text'])

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms_text'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[0.30348388]]),
#  'rank_': 1,
#  'singular_': array([137.63566545]),
#  'intercept_': array([2.99654342])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[0.30348388]]
# Intercepto: [2.99654342]
# y = [0.30348388]x + [2.99654342]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.052521679653830255

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('accommodates vs bathrooms_text')
plt.xlabel('Accommodates')
plt.ylabel('bathrooms_text')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['bathrooms_text']])
yPred
# Out:
# array([[4.66570476],
#        [3.3000273 ],
#        [3.3000273 ],
#        ...,
#        [3.3000273 ],
#        [3.3000273 ],
#        [3.3000273 ]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 5           6  165772   790208    10         5      city scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 5     BEST 5 Bedroom HOUSE IN S. Miguel Chapultepec
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# 3  Is the best ever place triple L <br />Location...
# 5  Welcome to Your Home in Mexico City<br />We ha...
#
#                                neighborhood_overview         host_name  ...  \
# 0                           No neighborhood_overview          Fernando  ...
# 1                           No neighborhood_overview          Nicholas  ...
# 2  Coyoacan is a beautiful neighborhood famous fo...            Trisha  ...
# 3  Is located in the best area of Mexico City, Po...            Andrea  ...
# 5  San Miguel Chapultepec is the best kept secret...  Francisco Carlos  ...
#
#   number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 0                    0.0                 4.58                   4.56
# 1                    0.0                 4.90                   4.81
# 2                    2.0                 4.91                   4.90
# 3                    0.0                 4.91                   5.00
# 5                    0.0                 4.88                   4.91
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      4.70                  4.87                        4.78
# 1                      4.75                  4.94                        4.92
# 2                      4.96                  4.96                        4.98
# 3                      5.00                  5.00                        4.73
# 5                      4.84                  4.92                        4.90
#
#   review_scores_location review_scores_value reviews_per_month Predicciones
# 0                   4.98                4.48              0.41     4.665705
# 1                   4.98                4.91              0.31     3.300027
# 2                   4.96                4.92              0.83     3.300027
# 3                   4.91                4.82              0.11     3.451769
# 5                   4.75                4.90              2.23     4.513963
#
# [5 rows x 50 columns]

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='accommodates', y='bathrooms_text', color='blue', data=df, label='Real')
sns.scatterplot(x='accommodates', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('accommodates')
plt.ylabel('bathrooms_text')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.052521679653830255

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.229176088747998
