# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# ...

# %%
df = df[df['room_type'] == 'Private room']

# %%
df['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['property_type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: property_type
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['price'] = df['price'].astype(float)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in minsu', '1', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in rental unit', '1.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in home', '2', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in condo', '2.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in guest suite', '3', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in serviced apartment', '3.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in townhouse', '4', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in bed and breakfast', '4.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in boutique hotel', '5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in guesthouse', '5.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in loft', '6', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in tiny home', '6.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in farm stay', '7', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in villa', '7.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in casa particular', '8', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in hotel', '8.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in floor', '9', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in cabin', '9.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in aparthotel', '10', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in hostel', '10.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in earthen home', '11', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in dorm', '11.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in hut', '12', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in dome', '12.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in vacation home', '13', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in barn', '13.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in cottage', '14', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in shipping container', '14.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in nature lodge', '15', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in tower', '15.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in lighthouse', '16', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in pension', '16.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in bungalow', '17', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in chalet', '17.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in tent', '18', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in castle', '18.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in houseboat', '19', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in resort', '19.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room', '20', regex=False)

# %%
df['property_type'] = df['property_type'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='property_type', x='price',  color = 'blue', data=df)
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_57776\1104701643.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['property_type']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[31.2573695]]),
#  'rank_': 1,
#  'singular_': array([248.73884301]),
#  'intercept_': array([651.84696168])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[31.2573695]]
# Intercepto: [651.84696168]
# y = [31.2573695]x + [651.84696168]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.0301547088227343

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['property_type']])
yPred
# Out:
# array([[1276.9943517 ],
#        [ 698.73301594],
#        [ 714.36170069],
#        ...,
#        [ 917.53460244],
#        [ 917.53460244],
#        [ 917.53460244]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#     Unnamed: 0       id   host_id  beds  bedrooms           source  \
# 4            5   131610    647454     1         2  previous scrape
# 6            7   171109    816295     1         1      city scrape
# 9           10  1013504   1664327     1         1      city scrape
# 10          11  1051636  22366411     1         1      city scrape
# 11          12  1066945   5870021     1         1      city scrape
#
#                                        name  \
# 4                            MARIA DEL ALMA
# 6           Cool room near WTC and Metrobus
# 9           OASIS IN COYOACAN, SHARED HOUSE
# 10  Chilango chic: room historic Condesa DF
# 11       Villa Alfonsina, Heart of Coyoacan
#
#                                           description  \
# 4                                      No description
# 6   Stay in a private room 2 blocks away from WTC,...
# 9   Private room (single bed) with private  bathro...
# 10  Like home! Private room in charming, tasteful ...
# ...

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='property_type', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.0301547088227343

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.0301547088227343

# %%
df = df[df['host_acceptance_rate'] != 'No data']
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_57776\1234139552.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('private bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('baths', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('shared bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('shared baths', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('shared', '', regex=False)

# %%
df = df.dropna(subset=['bathrooms_text'])
df['bathrooms_text'] = pd.to_numeric(df['bathrooms_text'], errors='coerce')
df['bathrooms_text'] = df['bathrooms_text'].astype(float)

# %%
df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_57776\1014031884.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)

# %%
df['instant_bookable'] = df['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_57776\4229115140.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['instant_bookable'] = df['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)

# %%
df = df[['host_acceptance_rate','host_is_superhost','price','accommodates','bathrooms_text','review_scores_cleanliness','host_identity_verified','instant_bookable','host_total_listings_count','review_scores_value','reviews_per_month','property_type']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7357 entries, 6 to 26579
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_acceptance_rate       7357 non-null   float64
#  1   host_is_superhost          7357 non-null   float64
#  2   price                      7357 non-null   float64
#  3   accommodates               7357 non-null   float64
#  4   bathrooms_text             7302 non-null   float64
#  5   review_scores_cleanliness  7357 non-null   float64
#  6   host_identity_verified     7357 non-null   int32
#  7   instant_bookable           7357 non-null   int32
#  8   host_total_listings_count  7357 non-null   float64
#  9   review_scores_value        7357 non-null   float64
#  10  reviews_per_month          7357 non-null   float64
#  11  property_type              7357 non-null   float64
# dtypes: float64(10), int32(2)
# memory usage: 689.7 KB

# %%
correlacion = df.corr()
correlacion
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.284088  0.077815
# host_is_superhost                      0.284088           1.000000 -0.025856
# price                                  0.077815          -0.025856  1.000000
# accommodates                           0.093324          -0.030167  0.312513
# bathrooms_text                        -0.078870          -0.110054 -0.039972
# review_scores_cleanliness             -0.008935           0.195028  0.095764
# host_identity_verified                -0.009850           0.037203 -0.035931
# instant_bookable                       0.356442          -0.013681  0.160360
# host_total_listings_count              0.225466          -0.082104  0.143460
# review_scores_value                   -0.050438           0.169247 -0.010808
# reviews_per_month                      0.159422           0.166260 -0.075603
# ...

# %%
corr = abs(correlacion)
corr
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.284088  0.077815
# host_is_superhost                      0.284088           1.000000  0.025856
# price                                  0.077815           0.025856  1.000000
# accommodates                           0.093324           0.030167  0.312513
# bathrooms_text                         0.078870           0.110054  0.039972
# review_scores_cleanliness              0.008935           0.195028  0.095764
# host_identity_verified                 0.009850           0.037203  0.035931
# instant_bookable                       0.356442           0.013681  0.160360
# host_total_listings_count              0.225466           0.082104  0.143460
# review_scores_value                    0.050438           0.169247  0.010808
# reviews_per_month                      0.159422           0.166260  0.075603
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.1f', linewidths=0.5, linecolor='black', cbar_kws={'shrink': 0.8}, annot_kws={"size": 10})
plt.title('Matriz de Correlaciones Private room Mexico', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.show()
