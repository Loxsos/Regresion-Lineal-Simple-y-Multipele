# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# 3  Is the best ever place triple L <br />Location...
# 4                                     No description
#
#                                neighborhood_overview host_name  ...  \
# 0                           No neighborhood_overview  Fernando  ...
# 1                           No neighborhood_overview  Nicholas  ...
# 2  Coyoacan is a beautiful neighborhood famous fo...    Trisha  ...
# 3  Is located in the best area of Mexico City, Po...    Andrea  ...
# 4                           No neighborhood_overview  Fernando  ...
#
#   number_of_reviews_ltm number_of_reviews_l30d review_scores_rating  \
# 0                   0.0                    0.0                 4.58
# 1                   4.0                    0.0                 4.90
# 2                   7.0                    2.0                 4.91
# 3                   0.0                    0.0                 4.91
# 4                   0.0                    0.0                 4.80
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.56                      4.70                  4.87
# 1                   4.81                      4.75                  4.94
# 2                   4.90                      4.96                  4.96
# 3                   5.00                      5.00                  5.00
# 4                   4.80                      4.80                  4.90
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.78                   4.98                4.48
# 1                        4.92                   4.98                4.91
# 2                        4.98                   4.96                4.92
# 3                        4.73                   4.91                4.82
# 4                        4.90                   4.90                4.80
#
#   reviews_per_month
# 0              0.41
# 1              0.31
# 2              0.83
# 3              0.11
# 4              1.17
#
# [5 rows x 49 columns]

# %%
df = df[df['room_type'] == 'Private room']

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='review_scores_cleanliness', x='price',  color = 'blue', data=df)
plt.title('price vs review_scores_cleanliness')
plt.xlabel('price')
plt.ylabel('review_scores_cleanliness')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_56232\3158968366.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['review_scores_cleanliness']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[209.12047908]]),
#  'rank_': 1,
#  'singular_': array([20.10568087]),
#  'intercept_': array([-250.917865])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[209.12047908]]
# Intercepto: [-250.917865]
# y = [209.12047908]x + [-250.917865]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.008818480649884664

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs review_scores_cleanliness')
plt.xlabel('price')
plt.ylabel('review_scores_cleanliness')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['review_scores_cleanliness']])
yPred
# Out:
# array([[752.86043458],
#        [713.12754355],
#        [777.95489207],
#        ...,
#        [752.86043458],
#        [752.86043458],
#        [752.86043458]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#     Unnamed: 0       id   host_id  beds  bedrooms           source  \
# 4            5   131610    647454     1         2  previous scrape
# 6            7   171109    816295     1         1      city scrape
# 9           10  1013504   1664327     1         1      city scrape
# 10          11  1051636  22366411     1         1      city scrape
# 11          12  1066945   5870021     1         1      city scrape
#
#                                        name  \
# 4                            MARIA DEL ALMA
# 6           Cool room near WTC and Metrobus
# 9           OASIS IN COYOACAN, SHARED HOUSE
# 10  Chilango chic: room historic Condesa DF
# 11       Villa Alfonsina, Heart of Coyoacan
#
#                                           description  \
# 4                                      No description
# 6   Stay in a private room 2 blocks away from WTC,...
# 9   Private room (single bed) with private  bathro...
# 10  Like home! Private room in charming, tasteful ...
# 11  In front of the Frida Kahlo Museum.<br /> Priv...
#
#                                 neighborhood_overview host_name  ...  \
# 4                            No neighborhood_overview  Fernando  ...
# 6   Great location, feel comfortable and secure at...    Carlos  ...
# 9   Her It's very safe, there are some restaurants...   Edoardo  ...
# 10  In the heart of the real Condesa! Chic yet sti...  Citlalli  ...
# 11  Our street "Allende" is privileged as it is on...    Héctor  ...
#
#    number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 4                     0.0                 4.80                   4.80
# 6                     0.0                 4.84                   4.87
# 9                     1.0                 4.96                   4.90
# 10                    0.0                 4.83                   4.60
# 11                    0.0                 4.93                   4.94
#
#    review_scores_cleanliness review_scores_checkin  \
# 4                       4.80                  4.90
# 6                       4.61                  4.98
# 9                       4.92                  4.92
# 10                      4.97                  4.97
# 11                      4.97                  4.96
#
#    review_scores_communication review_scores_location review_scores_value  \
# 4                         4.90                   4.90                4.80
# 6                         4.95                   4.97                4.81
# 9                         4.94                   4.92                4.89
# 10                        4.77                   4.93                4.73
# 11                        4.91                   4.97                4.94
#
#    reviews_per_month Predicciones
# 4               1.17   752.860435
# 6               0.84   713.127544
# 9               0.54   777.954892
# 10              0.22   788.410916
# 11              1.15   788.410916
#
# [5 rows x 50 columns]

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='review_scores_cleanliness', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('review_scores_cleanliness')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.008818480649884664

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.09390676573008286
