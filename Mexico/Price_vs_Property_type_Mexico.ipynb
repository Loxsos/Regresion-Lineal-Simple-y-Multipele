# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# ...

# %%
df = df[df['room_type'] == 'Entire home/apt']

# %%
df['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['property_type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: property_type
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['price'] = df['price'].astype(float)

# %%
df['property_type'] = df['property_type'].str.replace('Entire home','1', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire rental unit','1.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire loft', '2', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire condo', '2.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire guest suite', '3', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire serviced apartment', '3.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Tiny home', '4', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire guesthouse', '4.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire bungalow', '5', regex=False)
df['property_type'] = df['property_type'].str.replace('Casa particular', '5.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire townhouse','6', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire cabin', '6.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire villa', '7', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in aparthotel', '7.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire place', '8', regex=False)
df['property_type'] = df['property_type'].str.replace('Earthen home', '8.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire hostel', '9', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire cottage', '9.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire chalet', '10', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire in-law', '10.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Holiday park', '11', regex=False)
df['property_type'] = df['property_type'].str.replace('Campsite', '11.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Castle', '12', regex=False)
df['property_type'] = df['property_type'].str.replace('Farm stay', '12.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Hut', '13', regex=False)
df['property_type'] = df['property_type'].str.replace('1/apt', '13.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Entire vacation home', '14', regex=False)
df['property_type'] = df['property_type'].str.replace('Shipping container', '14.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Dome', '15', regex=False)
df['property_type'] = df['property_type'].str.replace('Tent', '15.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Boat', '16', regex=False)
df['property_type'] = df['property_type'].str.replace('Tower', '16.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in hotel', '17', regex=False)

# %%
df['property_type'] = df['property_type'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='property_type', x='price',  color = 'blue', data=df)
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_23032\1104701643.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['property_type']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-29.30819282]]),
#  'rank_': 1,
#  'singular_': array([189.75022703]),
#  'intercept_': array([1296.1427412])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-29.30819282]]
# Intercepto: [1296.1427412]
# y = [-29.30819282]x + [1296.1427412]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.005888442638820268

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['property_type']])
yPred
# Out:
# array([[1266.83454838],
#        [1252.18045197],
#        [1252.18045197],
#        ...,
#        [1252.18045197],
#        [1252.18045197],
#        [1252.18045197]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 5           6  165772   790208    10         5      city scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 5     BEST 5 Bedroom HOUSE IN S. Miguel Chapultepec
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# ...

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='property_type', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.005888442638820268

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.005888442638820268

# %%
df = df[df['host_acceptance_rate'] != 'No data']
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_23032\1234139552.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' baths', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace('Half-bath', '', regex=False)
df['bathrooms_text'] = pd.to_numeric(df['bathrooms_text'], errors='coerce')
df['bathrooms_text'] = df['bathrooms_text'].astype(float)

# %%
df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_23032\1014031884.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)

# %%
df['instant_bookable'] = df['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_23032\4229115140.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['instant_bookable'] = df['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)

# %%
df = df[['host_acceptance_rate','host_is_superhost','price','accommodates','bathrooms_text','review_scores_cleanliness','host_identity_verified','instant_bookable','host_total_listings_count','review_scores_value','reviews_per_month','property_type']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15929 entries, 0 to 26580
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_acceptance_rate       15929 non-null  float64
#  1   host_is_superhost          15929 non-null  float64
#  2   price                      15929 non-null  float64
#  3   accommodates               15929 non-null  float64
#  4   bathrooms_text             15919 non-null  float64
#  5   review_scores_cleanliness  15929 non-null  float64
#  6   host_identity_verified     15929 non-null  int32
#  7   instant_bookable           15929 non-null  int32
#  8   host_total_listings_count  15929 non-null  float64
#  9   review_scores_value        15929 non-null  float64
#  10  reviews_per_month          15929 non-null  float64
#  11  property_type              15929 non-null  float64
# dtypes: float64(10), int32(2)
# memory usage: 1.5 MB

# %%
correlacion = df.corr()
correlacion
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.243221  0.046501
# host_is_superhost                      0.243221           1.000000  0.042005
# price                                  0.046501           0.042005  1.000000
# accommodates                           0.019939           0.031786  0.232206
# bathrooms_text                        -0.010311           0.000650  0.170310
# review_scores_cleanliness              0.050762           0.223249  0.094213
# host_identity_verified                 0.002162           0.019719  0.012309
# instant_bookable                       0.278548           0.009634  0.096247
# host_total_listings_count              0.117229          -0.044887  0.053335
# review_scores_value                    0.004710           0.195316  0.063715
# reviews_per_month                      0.234300           0.187779 -0.054613
# ...

# %%
corr = abs(correlacion)
corr
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.243221  0.046501
# host_is_superhost                      0.243221           1.000000  0.042005
# price                                  0.046501           0.042005  1.000000
# accommodates                           0.019939           0.031786  0.232206
# bathrooms_text                         0.010311           0.000650  0.170310
# review_scores_cleanliness              0.050762           0.223249  0.094213
# host_identity_verified                 0.002162           0.019719  0.012309
# instant_bookable                       0.278548           0.009634  0.096247
# host_total_listings_count              0.117229           0.044887  0.053335
# review_scores_value                    0.004710           0.195316  0.063715
# reviews_per_month                      0.234300           0.187779  0.054613
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.1f', linewidths=0.5, linecolor='black', cbar_kws={'shrink': 0.8}, annot_kws={"size": 10})
plt.title('Matriz de Correlaciones Entire home/apt Mexico', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.show()
