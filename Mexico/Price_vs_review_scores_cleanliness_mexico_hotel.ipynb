# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# 3  Is the best ever place triple L <br />Location...
# 4                                     No description
#
#                                neighborhood_overview host_name  ...  \
# 0                           No neighborhood_overview  Fernando  ...
# 1                           No neighborhood_overview  Nicholas  ...
# 2  Coyoacan is a beautiful neighborhood famous fo...    Trisha  ...
# 3  Is located in the best area of Mexico City, Po...    Andrea  ...
# 4                           No neighborhood_overview  Fernando  ...
#
#   number_of_reviews_ltm number_of_reviews_l30d review_scores_rating  \
# 0                   0.0                    0.0                 4.58
# 1                   4.0                    0.0                 4.90
# 2                   7.0                    2.0                 4.91
# 3                   0.0                    0.0                 4.91
# 4                   0.0                    0.0                 4.80
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.56                      4.70                  4.87
# 1                   4.81                      4.75                  4.94
# 2                   4.90                      4.96                  4.96
# 3                   5.00                      5.00                  5.00
# 4                   4.80                      4.80                  4.90
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.78                   4.98                4.48
# 1                        4.92                   4.98                4.91
# 2                        4.98                   4.96                4.92
# 3                        4.73                   4.91                4.82
# 4                        4.90                   4.90                4.80
#
#   reviews_per_month
# 0              0.41
# 1              0.31
# 2              0.83
# 3              0.11
# 4              1.17
#
# [5 rows x 49 columns]

# %%
df = df[df['room_type'] == 'Hotel room']

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='review_scores_cleanliness', x='price',  color = 'blue', data=df)
plt.title('price vs review_scores_cleanliness')
plt.xlabel('price')
plt.ylabel('review_scores_cleanliness')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_32620\3158968366.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['review_scores_cleanliness']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[671.80805815]]),
#  'rank_': 1,
#  'singular_': array([1.92807676]),
#  'intercept_': array([-2147.81063016])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[671.80805815]]
# Intercepto: [-2147.81063016]
# y = [671.80805815]x + [-2147.81063016]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.07152241886943667

# %%
plt.figure(figsize=(8, 6))
plt.scatter(indep, dep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs review_scores_cleanliness')
plt.xlabel('price')
plt.ylabel('review_scores_cleanliness')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['review_scores_cleanliness']])
yPred
# Out:
# array([[1211.22966058],
#        [1211.22966058],
#        [1191.07541883],
#        [1211.22966058],
#        [1103.74037127],
#        [1170.92117709],
#        [1123.89461302],
#        [1191.07541883],
#        [1211.22966058],
#        [ 761.11826162],
#        [1164.20309651],
#        [1130.6126936 ],
#        [1076.86804895],
#        [1211.22966058],
#        [1144.04885476],
#        [ 969.37875964],
#        [1016.40532371],
#        [1076.86804895],
#        [1150.76693534],
#        [1211.22966058],
#        [1076.86804895],
#        [1150.76693534],
#        [1211.22966058],
#        [ 922.35219557],
#        [ 976.09684023],
#        [1090.30421011],
#        [1076.86804895],
#        [1164.20309651],
#        [1137.33077418],
#        [ 875.3256315 ],
#        [ 875.3256315 ],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [ 828.29906743],
#        [ 835.01714801],
#        [ 922.35219557],
#        [ 828.29906743],
#        [ 673.78321406],
#        [1076.86804895],
#        [1009.68724313],
#        [ 882.04371208],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1076.86804895],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1076.86804895],
#        [1036.55956546],
#        [1211.22966058],
#        [1076.86804895],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1177.63925767],
#        [1164.20309651],
#        [1211.22966058],
#        [1144.04885476],
#        [1076.86804895],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1076.86804895],
#        [1076.86804895],
#        [ 989.53300139],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [1076.86804895],
#        [ 808.14482569],
#        [1211.22966058],
#        [1211.22966058],
#        [1211.22966058],
#        [ 955.94259848],
#        [ 539.42160243],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895],
#        [1076.86804895]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#      Unnamed: 0       id  host_id  beds  bedrooms           source  \
# 47           48   281134   196253     1         1  previous scrape
# 61           62  1565220  2518152     1         1  previous scrape
# 74           75  1736063  2518152     1         1  previous scrape
# 99          100   571166   196253     1         1      city scrape
# 134         135   737328  3850198     1         1      city scrape
#
#                                                   name  \
# 47                  COOL PENT HOUSE APARTMENT @CONDESA
# 61   Descansa en la Suite de la Abuelita San Angel ...
# 74         Cómodo Estudio del Botánico, San Angel CDMX
# 99   MODERN/HIP FURNISHED APARTMENT ( S1 Condesa Haus)
# 134                  Business Suite BEIGE near Reforma
#
#                                            description  \
# 47   Amazing Pent House apartment in the heart fo C...
# 61   Beautiful, spacious and calm independent Suite...
# 74   Small, very practical and beautiful independen...
# 99   This is a one bedroom furnished apartment in t...
# 134                                     No description
#
#                                  neighborhood_overview     host_name  ...  \
# 47                            No neighborhood_overview      Fernando  ...
# 61   San Ángel is a XVI century village nestled in ...  Martha Laura  ...
# 74   San Ángel is a XVI century village nestled in ...  Martha Laura  ...
# 99                            No neighborhood_overview      Fernando  ...
# 134  The area in which our service is located stand...       Hermann  ...
#
#     number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 47                     0.0                 4.71                   4.71
# 61                     0.0                 4.96                   5.00
# 74                     0.0                 4.88                   4.84
# 99                     0.0                 4.00                   5.00
# 134                    0.0                 4.84                   4.88
#
#     review_scores_cleanliness review_scores_checkin  \
# 47                       5.00                  5.00
# 61                       5.00                  5.00
# 74                       4.97                  4.89
# 99                       5.00                  5.00
# 134                      4.84                  5.00
#
#     review_scores_communication review_scores_location review_scores_value  \
# 47                         5.00                   5.00                4.86
# 61                         4.96                   4.93                4.93
# 74                         4.93                   4.96                4.86
# 99                         4.90                   5.00                4.00
# 134                        5.00                   4.84                4.80
#
#     reviews_per_month Predicciones
# 47               0.06  1211.229661
# 61               0.21  1211.229661
# 74               0.45  1191.075419
# 99               0.01  1211.229661
# 134              0.18  1103.740371
#
# [5 rows x 50 columns]

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='review_scores_cleanliness', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('review_scores_cleanliness')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.07152241886943667

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.2674367567658505
