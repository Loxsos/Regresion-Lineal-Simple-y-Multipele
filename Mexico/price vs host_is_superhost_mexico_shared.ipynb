# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('listings - CDMX_clean.xlsx') 
df.head()
# Out:
#    Unnamed: 0      id  host_id  beds  bedrooms           source  \
# 0           1   44616   196253     1         5  previous scrape
# 1           2   67703   334451     2         2      city scrape
# 2           3   70644   212109     1         1      city scrape
# 3           4  107078   540705     1         1      city scrape
# 4           5  131610   647454     1         2  previous scrape
#
#                                                name  \
# 0                                      Condesa Haus
# 1                 2 bedroom apt. deco bldg, Condesa
# 2  Beautiful light Studio Coyoacan- full equipped !
# 3                                NEW  DESIGNER LOFT
# 4                                    MARIA DEL ALMA
#
#                                          description  \
# 0  A new concept of hosting in mexico through a b...
# 1  Comfortably furnished, sunny, 2 bedroom apt., ...
# 2  COYOACAN designer studio quiet & safe! well eq...
# 3  Is the best ever place triple L <br />Location...
# 4                                     No description
#
#                                neighborhood_overview host_name  ...  \
# 0                           No neighborhood_overview  Fernando  ...
# 1                           No neighborhood_overview  Nicholas  ...
# 2  Coyoacan is a beautiful neighborhood famous fo...    Trisha  ...
# 3  Is located in the best area of Mexico City, Po...    Andrea  ...
# 4                           No neighborhood_overview  Fernando  ...
#
#   number_of_reviews_ltm number_of_reviews_l30d review_scores_rating  \
# 0                   0.0                    0.0                 4.58
# 1                   4.0                    0.0                 4.90
# 2                   7.0                    2.0                 4.91
# 3                   0.0                    0.0                 4.91
# 4                   0.0                    0.0                 4.80
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.56                      4.70                  4.87
# 1                   4.81                      4.75                  4.94
# 2                   4.90                      4.96                  4.96
# 3                   5.00                      5.00                  5.00
# 4                   4.80                      4.80                  4.90
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.78                   4.98                4.48
# 1                        4.92                   4.98                4.91
# 2                        4.98                   4.96                4.92
# 3                        4.73                   4.91                4.82
# 4                        4.90                   4.90                4.80
#
#   reviews_per_month
# 0              0.41
# 1              0.31
# 2              0.83
# 3              0.11
# 4              1.17
#
# [5 rows x 49 columns]

# %%
df = df[df['room_type'] == 'Shared room']

# %%
df['host_is_superhost'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 8693 entries, 4 to 26579
# Series name: host_is_superhost
# Non-Null Count  Dtype
# --------------  -----
# 8693 non-null   object
# dtypes: object(1)
# memory usage: 135.8+ KB

# %%
df['price'] = df['price'].astype(float)

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_38756\1234139552.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(x='price', y='host_is_superhost',  color = 'blue', data=df)
plt.title('Price vs Host Is Superhost')
plt.xlabel('Host Is Superhost')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_38756\3507105617.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['host_is_superhost']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-105.55848338]]),
#  'rank_': 1,
#  'singular_': array([6.0008312]),
#  'intercept_': array([450.44598338])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-105.55848338]]
# Intercepto: [450.44598338]
# y = [-105.55848338]x + [450.44598338]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.005979114223561899

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('Host_Is_Superhost vs Price')
plt.xlabel('Host_Is_SuperHost')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['host_is_superhost']])
yPred
# Out:
# array([[450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [450.44598338],
#        [344.8875    ],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [344.8875    ],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338],
#        [450.44598338]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#      Unnamed: 0       id   host_id  beds  bedrooms           source  \
# 114         115   617137   3059169     1         1  previous scrape
# 257         258  3197924  16186468     2         2      city scrape
# 365         366  5434219  28190065    18         1      city scrape
# 443         444  6972071  35406862    16         1      city scrape
# 455         456  6076798  31426842    12         1      city scrape
#
#                                               name  \
# 114                Apt near Mexico City's downtown
# 257               cuarto con terraza y uso general
# 365                        メキシコシティの革命記念塔付近のホステルです。
# 443  SUPER SAVER GROUP DEAL - PERFECT FOR STUDENTS
# 455                                     Nova House
#
#                                            description  \
# 114                                     No description
# 257  double bed , full bathroom, room with own terr...
# 365  Single Room $30<br />Double room $60<br />Dorm...
# 443  Welcome to the best college-style dorms in a B...
# 455  It has all the comforts to rest if you come fo...
#
#                                  neighborhood_overview host_name  ...  \
# 114                           No neighborhood_overview    Andoni  ...
# 257  Condesa is the main attraction in the city for...     Jordi  ...
# 365                           No neighborhood_overview    Tetsuo  ...
# 443                           No neighborhood_overview      Thor  ...
# 455  The neighborhood is popular where you can expe...   Antonio  ...
#
#     number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 114                    0.0                 4.80                   4.80
# 257                    0.0                 4.80                   4.80
# 365                    2.0                 4.44                   4.74
# 443                    0.0                 4.80                   4.80
# 455                    0.0                 4.85                   4.84
#
#     review_scores_cleanliness review_scores_checkin  \
# 114                      4.80                  4.90
# 257                      4.80                  4.90
# 365                      4.47                  4.74
# 443                      4.80                  4.90
# 455                      4.93                  4.94
#
#     review_scores_communication  review_scores_location review_scores_value  \
# 114                        4.90                    4.90                4.80
# 257                        4.90                    4.90                4.80
# 365                        4.71                    4.71                4.59
# 443                        4.90                    4.90                4.80
# 455                        4.91                    4.69                4.93
#
#     reviews_per_month Predicciones
# 114             0.135   450.445983
# 257             1.195   450.445983
# 365             0.300   344.887500
# 443             0.165   450.445983
# 455             0.750   344.887500
#
# [5 rows x 50 columns]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='price', y='host_is_superhost', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('Host Is Superhost')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.005979114223561899

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.07732473228897659
