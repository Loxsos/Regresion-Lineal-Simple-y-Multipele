# %% [markdown]
# <a href="https://colab.research.google.com/github/Loxsos/Regresion-Lineal-Simple-y-Multipele/blob/main/price_vs_host_is_superhost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1pkLk2s89-Etn7zIuYV88L_FvDH3sI8qx')
df.head()
# Out:
#    Unnamed: 0           source  \
# 0           0      city scrape
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# 0  It is very center of Bangkok and easy access t...      Nuttee  08/05/2010
# 1  It is very center of Bangkok and easy access t...         Emy  08/05/2010
# 2  Ramkumheang neigbourhood - hip place with food...  Familyroom  12/05/2010
# 3  There is McDonald's, Au bon Pain and Max Value...     Sirilak  27/06/2010
# 4  There is McDonald's, Au bon Pain and Max Value...    Athitaya  03/09/2010
#
#        host_location                                         host_about  \
# 0  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 1  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 2  Bangkok, Thailand  Welcome to Familyroom Apartment.\r\n\r\nA Chic...
# 3  Bangkok, Thailand  from Bangkok but I'm in and out of the city a ...
# 4  Bangkok, Thailand  Full-time legal consultant from Bangkok, Thail...
#
#   host_response_time  ... number_of_reviews_l30d review_scores_rating  \
# 0     within an hour  ...                    0.0                 4.86
# 1     within an hour  ...                    0.0                 4.70
# 2     within an hour  ...                    0.0                 4.70
# 3     within an hour  ...                    0.0                 4.83
# 4     within an hour  ...                    0.0                 5.00
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.95                      4.82                  4.97
# 1                   4.70                      4.70                  4.80
# 2                   4.70                      4.70                  4.80
# 3                   5.00                      4.67                  4.50
# 4                   5.00                      5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.91                   4.66                4.75
# 1                        4.80                   4.60                4.70
# 2                        4.80                   4.60                4.70
# 3                        4.83                   4.83                5.00
# 4                        5.00                   5.00                5.00
#
#   reviews_per_month Precio Venta
# 0              0.43         4.95
# 1              1.00         4.70
# 2              1.00         4.70
# 3              0.06         5.00
# 4              0.01         5.00
#
# [5 rows x 48 columns]

# %%
df = df[df['room_type'] == 'Entire home/apt']

# %%
df['host_is_superhost'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: host_is_superhost
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['price'] = df['price'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2b1de35abd00> in <cell line: 0>()
# ----> 1 df['price'] = df['price'].str.replace('$', '').str.replace(',', '').astype(float)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     189         from pandas.core.arrays.string_ import StringDtype
#     190
# --> 191         self._inferred_dtype = self._validate(data)
#     192         self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     243
#     244         if inferred_dtype not in allowed_types:
# --> 245             raise AttributeError("Can only use .str accessor with string values!")
#     246         return inferred_dtype
#     247
#
# AttributeError: Can only use .str accessor with string values!

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# <ipython-input-6-1126a6e5cd06>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)

# %%
df['host_is_superhost'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: host_is_superhost
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  float64
# dtypes: float64(1)
# memory usage: 248.2 KB

# %%
df['host_is_superhost'].head()
# Out:
# 0     0.0
# 8     0.0
# 9     0.0
# 13    0.0
# 14    0.0
# Name: host_is_superhost, dtype: float64

# %%
df['price'].head()
# Out:
# 0     1793.0
# 8     1369.0
# 9     5347.0
# 13    1090.0
# 14    2480.0
# Name: price, dtype: float64

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='price', x='host_is_superhost',  color = 'blue', data=df)
plt.title('Price vs Host Is Superhost')
plt.xlabel('Host Is Superhost')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-19-d10eb31f3884>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(y='price', x='host_is_superhost',  palette={0: 'red', 1: 'blue'}, data=df)
# <ipython-input-19-d10eb31f3884>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['host_is_superhost']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-712.45971707]]),
#  'rank_': 1,
#  'singular_': array([59.96405386]),
#  'intercept_': array([2910.52989889])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-712.45971707]]
# Intercepto: [2910.52989889]
# y = [-712.45971707]x + [2910.52989889]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.0004189452491248913

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('Host_Is_Superhost vs Price')
plt.xlabel('Host_Is_SuperHost')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['host_is_superhost']])
yPred
# Out:
# array([[2910.52989889],
#        [2910.52989889],
#        [2910.52989889],
#        ...,
#        [2910.52989889],
#        [2910.52989889],
#        [2910.52989889]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#     Unnamed: 0           source  \
# 0            0      city scrape
# 8            8      city scrape
# 9            9      city scrape
# 13          13      city scrape
# 14          14  previous scrape
#
#                                               name  \
# 0                  Nice room with superb city view
# 8   Cozy and spacious 1BR with great view, LT rent
# 9              Central Bangkok 3 Bedroom Apartment
# 13  Studio near Chula University/Silom walk to MRT
# 14               Nice and Cozy Room @ Sathorn Area
#
#                                           description  \
# 0   Our cool and comfortable one bedroom apartment...
# 8   The cozy one bed room apartment, conveniently ...
# 9   We are Airbnb Super Hosts. Book our apartment ...
# 13  A centrally located studio apartment with wifi...
# 14  A centrally located studio apartment with wifi...
#
#                                 neighborhood_overview host_name  host_since  \
# 0   It is very center of Bangkok and easy access t...    Nuttee  08/05/2010
# 8   Charoen krung street, River pier, Iconsiam, Su...      Jean  27/10/2010
# 9   Sukhumvit Rd is the shopping and restaurant di...     Henry  30/04/2011
# 13  It's central yet very local - you'll find easi...      Gael  01/12/2009
# 14  It's central yet very local - you'll find easi...     Wirat  01/07/2011
#
#            host_location                                         host_about  \
# 0      Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 8   Nonthaburi, Thailand  I love traveling and experience local culture,...
# 9      Bangkok, Thailand  Hello!\r\n\r\nOur collection of privately owne...
# 13    Ko Samui, Thailand  I'm french, living in Samui and Bangkok.\r\n\r...
# 14     Bangkok, Thailand  Nice and Cozy Room @ Sathorn Area. \r\nOne Bed...
#
#     host_response_time  ... review_scores_rating review_scores_accuracy  \
# 0       within an hour  ...                 4.86                   4.95
# 8   within a few hours  ...                 4.88                   4.71
# 9   a few days or more  ...                 4.77                   4.84
# 13  within a few hours  ...                 4.80                   4.56
# 14  within a few hours  ...                 4.70                   4.70
#
#     review_scores_cleanliness review_scores_checkin  \
# 0                        4.82                  4.97
# 8                        4.82                  4.81
# 9                        4.85                  4.86
# 13                       4.80                  4.90
# 14                       4.70                  4.80
#
#    review_scores_communication review_scores_location review_scores_value  \
# 0                         4.91                   4.66                4.75
# 8                         4.69                   4.50                4.80
# 9                         4.89                   4.86                4.76
# 13                        4.90                   4.35                4.80
# 14                        4.80                   4.60                4.70
#
#    reviews_per_month Precio Venta Predicciones
# 0               0.43         4.95  2910.529899
# 8               0.11         4.71  2910.529899
# 9               0.93         4.84  2910.529899
# 13              0.47         4.56  2910.529899
# 14              1.00         4.70  2910.529899
#
# [5 rows x 49 columns]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='price', y='host_is_superhost', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('Host Is Superhost')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.0004189452491248913

# %%
coefCo = np.sqrt(coefDe)
coefCo

# %%
df = df[['host_is_superhost', 'price']]
df
# Out:
#        host_is_superhost   price
# 0                    0.0  1793.0
# 8                    0.0  1369.0
# 9                    0.0  5347.0
# 13                   0.0  1090.0
# 14                   0.0  2480.0
# ...                  ...     ...
# 25074                0.0  1700.0
# 25075                0.0  1700.0
# 25076                0.0  2500.0
# 25077                0.0  1700.0
# 25078                0.0  1700.0
#
# [15885 rows x 2 columns]

# %%
sns.pairplot(df, diag_kind='kde', plot_kws={'alpha': 0.8, 'edgecolor': 'k'})
plt.suptitle('Pairplot de Variables Numéricas', y=1.02)
plt.show()

# %%
correlacion = df.corr()
correlacion
# Out:
#                    host_is_superhost     price
# host_is_superhost           1.000000 -0.020468
# price                      -0.020468  1.000000

# %%
corr = abs(correlacion)
corr
# Out:
#                    host_is_superhost     price
# host_is_superhost           1.000000  0.020468
# price                       0.020468  1.000000

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black', cbar_kws={'shrink': 0.8}, annot_kws={"size": 10})
plt.title('Matriz de Correlaciones', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.show()
