# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1pkLk2s89-Etn7zIuYV88L_FvDH3sI8qx')
df.head()
# Out:
#    Unnamed: 0           source  \
# 0           0      city scrape
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# 0  It is very center of Bangkok and easy access t...      Nuttee  08/05/2010
# 1  It is very center of Bangkok and easy access t...         Emy  08/05/2010
# 2  Ramkumheang neigbourhood - hip place with food...  Familyroom  12/05/2010
# 3  There is McDonald's, Au bon Pain and Max Value...     Sirilak  27/06/2010
# 4  There is McDonald's, Au bon Pain and Max Value...    Athitaya  03/09/2010
#
#        host_location                                         host_about  \
# 0  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 1  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 2  Bangkok, Thailand  Welcome to Familyroom Apartment.\r\n\r\nA Chic...
# 3  Bangkok, Thailand  from Bangkok but I'm in and out of the city a ...
# 4  Bangkok, Thailand  Full-time legal consultant from Bangkok, Thail...
#
#   host_response_time  ... number_of_reviews_l30d review_scores_rating  \
# 0     within an hour  ...                    0.0                 4.86
# 1     within an hour  ...                    0.0                 4.70
# 2     within an hour  ...                    0.0                 4.70
# 3     within an hour  ...                    0.0                 4.83
# 4     within an hour  ...                    0.0                 5.00
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.95                      4.82                  4.97
# 1                   4.70                      4.70                  4.80
# 2                   4.70                      4.70                  4.80
# 3                   5.00                      4.67                  4.50
# 4                   5.00                      5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.91                   4.66                4.75
# 1                        4.80                   4.60                4.70
# 2                        4.80                   4.60                4.70
# 3                        4.83                   4.83                5.00
# 4                        5.00                   5.00                5.00
#
#   reviews_per_month Precio Venta
# 0              0.43         4.95
# 1              1.00         4.70
# 2              1.00         4.70
# 3              0.06         5.00
# 4              0.01         5.00
#
# [5 rows x 48 columns]

# %%
df = df[df['room_type'] == 'Shared room']

# %%
df['price'] = df['price'].str.replace('$', '', regex=False)
df['price'] = df['price'].str.replace('.00', '', regex=False)
df['price'] = df['price'].str.replace(',000', '', regex=False)
df['price'] = df['price'].str.replace(',', '.', regex=False)
df['price'] = df['price'].astype(float)
# Out:
# <ipython-input-4-9a1f568ff3ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('$', '', regex=False)
# <ipython-input-4-9a1f568ff3ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('.00', '', regex=False)
# <ipython-input-4-9a1f568ff3ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace(',000', '', regex=False)
# <ipython-input-4-9a1f568ff3ef>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace(',', '.', regex=False)
# <ipython-input-4-9a1f568ff3ef>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].astype(float)

# %%
df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%', '', regex=False)
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)
# Out:
# <ipython-input-5-c2479742cf16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%', '', regex=False)
# <ipython-input-5-c2479742cf16>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='host_acceptance_rate', x='price',  color = 'blue', data=df)
plt.title('price vs host_acceptance_rate')
plt.xlabel('price')
plt.ylabel('host_acceptance_rate')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-6-e42f9d927c88>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['host_acceptance_rate']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[0.38533755]]),
#  'rank_': 1,
#  'singular_': array([583.76136939]),
#  'intercept_': array([796.5179199])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[0.38533755]]
# Intercepto: [796.5179199]
# y = [0.38533755]x + [796.5179199]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.00012233890258162017

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep['price'], indep['host_acceptance_rate'], color='blue')
plt.plot(indep['host_acceptance_rate'], model.predict(indep), color='red')
plt.title('price vs host_acceptance_rate')
plt.xlabel('price')
plt.ylabel('host_acceptance_rate')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['host_acceptance_rate']])
yPred
# Out:
# array([[831.96897412],
#        [834.28099939],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [830.81296148],
#        [835.05167449],
#        [830.42762394],
#        [835.05167449],
#        [823.10621057],
#        [823.10621057],
#        [823.10621057],
#        [823.10621057],
#        [823.10621057],
#        [823.10621057],
#        [835.05167449],
#        [833.89566185],
#        [823.10621057],
#        [823.10621057],
#        [831.96897412],
#        [835.05167449],
#        [825.41823584],
#        [825.41823584],
#        [825.41823584],
#        [835.05167449],
#        [825.41823584],
#        [833.89566185],
#        [835.05167449],
#        [835.05167449],
#        [820.79418529],
#        [820.79418529],
#        [820.79418529],
#        [820.79418529],
#        [831.96897412],
#        [834.66633694],
#        [828.11559866],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [828.11559866],
#        [796.5179199 ],
#        [833.89566185],
#        [833.89566185],
#        [820.79418529],
#        [820.79418529],
#        [820.79418529],
#        [824.2622232 ],
#        [833.12498676],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [827.73026112],
#        [824.2622232 ],
#        [824.2622232 ],
#        [835.05167449],
#        [835.05167449],
#        [824.2622232 ],
#        [831.19829903],
#        [835.05167449],
#        [796.5179199 ],
#        [835.05167449],
#        [804.22467082],
#        [835.05167449],
#        [826.95958602],
#        [835.05167449],
#        [835.05167449],
#        [831.19829903],
#        [835.05167449],
#        [796.5179199 ],
#        [824.2622232 ],
#        [835.05167449],
#        [835.05167449],
#        [831.58363657],
#        [830.42762394],
#        [835.05167449],
#        [832.35431166],
#        [833.5103243 ],
#        [835.05167449],
#        [834.28099939],
#        [833.89566185],
#        [834.28099939],
#        [835.05167449],
#        [796.5179199 ],
#        [816.55547229],
#        [835.05167449],
#        [835.05167449],
#        [834.66633694],
#        [835.05167449],
#        [833.89566185],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [834.66633694],
#        [834.66633694],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [834.66633694],
#        [835.05167449],
#        [830.42762394],
#        [830.42762394],
#        [834.66633694],
#        [834.66633694],
#        [828.50093621],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [835.05167449],
#        [833.12498676],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [828.50093621],
#        [832.35431166],
#        [834.66633694],
#        [835.05167449],
#        [835.05167449],
#        [833.89566185],
#        [833.5103243 ],
#        [835.05167449],
#        [829.65694884],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        [834.66633694],
#        

#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [835.05167449],
#        [834.66633694],
#        [822.33553547],
#        [835.05167449],
#        [835.05167449],
#        [833.5103243 ],
#        [831.96897412],
#        [834.66633694]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#      Unnamed: 0           source                                 name  \
# 117         117  previous scrape  Near Bangkok more space than urban!
# 174         174  previous scrape    BANGKOK HUB DORM public transport
# 217         217      city scrape     S1 hostel (Dorm) Sathorn Bangkok
# 229         229  previous scrape   BANGKOK HUB : Standard Double Room
# 277         277  previous scrape               k79room near BTS Onnut
#
#                                            description  \
# 117  IHouse Ekkamai Condo 56 sqm. 1 bedroom, 1 livi...
# 174  Nested in the heart of bustling Bangkok, Bangk...
# 217  Stylish budget hostel in the midst of Bangkok,...
# 229  A room with minimalism & rustic design in Cult...
# 277  k79room HOSTEL is the best budget hostel becau...
#
#                                  neighborhood_overview   host_name  \
# 117                         night-out street "Ekkamai"   Sugarcane
# 174  Many street food around, you wont worry about ...  Kriengkrai
# 217  Our hostel is located on small greenery road. ...          S1
# 229  Taking AIRPORT LINK to PHAYATHAI, then Sky Tra...  Kriengkrai
# 277  7-11, Tesco Lotus, Big C, Massage, BTS On Nut,...       Warut
#
#      host_since      host_location  \
# 117  02/02/2013  Bangkok, Thailand
# 174  06/09/2013  Bangkok, Thailand
# 217  19/11/2013  Bangkok, Thailand
# 229  06/09/2013  Bangkok, Thailand
# 277  21/02/2014  Bangkok, Thailand
#
#                                             host_about  host_response_time  \
# 117  Investor relations manager in a high-end real ...      within an hour
# 174  My inspiration is to have a place where friend...  within a few hours
# 217  We are very welcome all our guests as our own ...      within an hour
# 229  My inspiration is to have a place where friend...      within an hour
# 277  Our Aries building is a low rise, boutique bui...      within an hour
#
#      ... review_scores_rating  review_scores_accuracy  \
# 117  ...                 4.70                    4.70
# 174  ...                 4.44                    4.80
# 217  ...                 4.53                    4.61
# 229  ...                 5.00                    5.00
# 277  ...                 4.80                    4.67
#
#     review_scores_cleanliness review_scores_checkin  \
# 117                      4.70                  4.80
# 174                      4.80                  4.69
# 217                      4.73                  4.73
# 229                      5.00                  5.00
# 277                      4.50                  4.90
#
#     review_scores_communication review_scores_location review_scores_value  \
# 117                        4.80                   4.60                4.70
# 174                        4.69                   4.73                4.56
# 217                        4.62                   4.37                4.59
# 229                        5.00                   4.50                4.50
# 277                        4.67                   4.67                4.80
#
#     reviews_per_month Precio Venta Predicciones
# 117              1.00         4.70   831.968974
# 174              0.21         4.80   834.280999
# 217              0.76         4.61   835.051674
# 229              0.02         5.00   835.051674
# 277              0.03         4.67   835.051674
#
# [5 rows x 49 columns]

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='host_acceptance_rate', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('host_acceptance_rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.00012233890258162017

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.011060691776811257
