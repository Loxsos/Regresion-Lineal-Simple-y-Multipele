# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1pkLk2s89-Etn7zIuYV88L_FvDH3sI8qx')
df.head()
# Out:
#    Unnamed: 0           source  \
# 0           0      city scrape
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# 0  It is very center of Bangkok and easy access t...      Nuttee  08/05/2010
# 1  It is very center of Bangkok and easy access t...         Emy  08/05/2010
# 2  Ramkumheang neigbourhood - hip place with food...  Familyroom  12/05/2010
# 3  There is McDonald's, Au bon Pain and Max Value...     Sirilak  27/06/2010
# 4  There is McDonald's, Au bon Pain and Max Value...    Athitaya  03/09/2010
#
#        host_location                                         host_about  \
# 0  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 1  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 2  Bangkok, Thailand  Welcome to Familyroom Apartment.\r\n\r\nA Chic...
# 3  Bangkok, Thailand  from Bangkok but I'm in and out of the city a ...
# 4  Bangkok, Thailand  Full-time legal consultant from Bangkok, Thail...
#
#   host_response_time  ... number_of_reviews_l30d review_scores_rating  \
# 0     within an hour  ...                    0.0                 4.86
# 1     within an hour  ...                    0.0                 4.70
# 2     within an hour  ...                    0.0                 4.70
# 3     within an hour  ...                    0.0                 4.83
# 4     within an hour  ...                    0.0                 5.00
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.95                      4.82                  4.97
# 1                   4.70                      4.70                  4.80
# 2                   4.70                      4.70                  4.80
# 3                   5.00                      4.67                  4.50
# 4                   5.00                      5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.91                   4.66                4.75
# 1                        4.80                   4.60                4.70
# 2                        4.80                   4.60                4.70
# 3                        4.83                   4.83                5.00
# 4                        5.00                   5.00                5.00
#
#   reviews_per_month Precio Venta
# 0              0.43         4.95
# 1              1.00         4.70
# 2              1.00         4.70
# 3              0.06         5.00
# 4              0.01         5.00
#
# [5 rows x 48 columns]

# %%
df = df[df['room_type'] == 'Private room']

# %%
df['price'] = df['price'].str.replace('$', '', regex=False)
df['price'] = df['price'].str.replace('.00', '', regex=False)
df['price'] = df['price'].str.replace(',000', '', regex=False)
df['price'] = df['price'].str.replace(',', '.', regex=False)
df['price'] = df['price'].astype(float)

# %%
df['instant_bookable'] = df['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)
# Out:
# <ipython-input-24-2ecc90ab2ff6>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['instant_bookable'] = df['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='instant_bookable', x='price',  color = 'blue', data=df)
plt.title('price vs instant_bookable')
plt.xlabel('price')
plt.ylabel('instant_bookable')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-25-0e99b94ff819>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['instant_bookable']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-470.13536293]]),
#  'rank_': 1,
#  'singular_': array([43.66708599]),
#  'intercept_': array([1196.23343547])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-470.13536293]]
# Intercepto: [1196.23343547]
# y = [-470.13536293]x + [1196.23343547]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.044961648410192234

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs instant_bookable')
plt.xlabel('price')
plt.ylabel('instant_bookable')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['instant_bookable']])
yPred
# Out:
# array([[1196.23343547],
#        [1196.23343547],
#        [1196.23343547],
#        ...,
#        [1196.23343547],
#        [1196.23343547],
#        [1196.23343547]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#    Unnamed: 0           source  \
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
# 5           5      city scrape
#
#                                              name  \
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
# 5                   Sathorn Terrace Apartment(61)
#
#                                          description  \
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
# 5  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# 1  It is very center of Bangkok and easy access t...         Emy  08/05/2010
# 2  Ramkumheang neigbourhood - hip place with food...  Familyroom  12/05/2010
# 3  There is McDonald's, Au bon Pain and Max Value...     Sirilak  27/06/2010
# 4  There is McDonald's, Au bon Pain and Max Value...    Athitaya  03/09/2010
# 5  There is McDonald's, Au bon Pain and Max Value...         Tor  15/10/2010
#
#        host_location                                         host_about  \
# 1  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 2  Bangkok, Thailand  Welcome to Familyroom Apartment.\r\n\r\nA Chic...
# 3  Bangkok, Thailand  from Bangkok but I'm in and out of the city a ...
# 4  Bangkok, Thailand  Full-time legal consultant from Bangkok, Thail...
# 5  Bangkok, Thailand  Hello, my name is Tor, Escape at sathorn terra...
#
#    host_response_time  ... review_scores_rating review_scores_accuracy  \
# 1      within an hour  ...                 4.70                    4.7
# 2      within an hour  ...                 4.70                    4.7
# 3      within an hour  ...                 4.83                    5.0
# 4      within an hour  ...                 5.00                    5.0
# 5  within a few hours  ...                 4.79                    4.7
#
#   review_scores_cleanliness review_scores_checkin  \
# 1                      4.70                  4.80
# 2                      4.70                  4.80
# 3                      4.67                  4.50
# 4                      5.00                  5.00
# 5                      4.85                  4.82
#
#    review_scores_communication review_scores_location review_scores_value  \
# 1                         4.80                   4.60                4.70
# 2                         4.80                   4.60                4.70
# 3                         4.83                   4.83                5.00
# 4                         5.00                   5.00                5.00
# 5                         4.88                   4.76                4.84
#
#   reviews_per_month Precio Venta Predicciones
# 1              1.00          4.7  1196.233435
# 2              1.00          4.7  1196.233435
# 3              0.06          5.0  1196.233435
# 4              0.01          5.0  1196.233435
# 5              0.21          4.7  1196.233435
#
# [5 rows x 49 columns]

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='instant_bookable', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Predicciones')
plt.ylabel('instant_bookable')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.044961648410192234

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.21204161952360256
