# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1pkLk2s89-Etn7zIuYV88L_FvDH3sI8qx')
df.head()
# Out:
#    Unnamed: 0           source  \
# 0           0      city scrape
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# 0  It is very center of Bangkok and easy access t...      Nuttee  08/05/2010
# 1  It is very center of Bangkok and easy access t...         Emy  08/05/2010
# 2  Ramkumheang neigbourhood - hip place with food...  Familyroom  12/05/2010
# 3  There is McDonald's, Au bon Pain and Max Value...     Sirilak  27/06/2010
# 4  There is McDonald's, Au bon Pain and Max Value...    Athitaya  03/09/2010
#
#        host_location                                         host_about  \
# 0  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 1  Bangkok, Thailand  Hi All, I am nuttee patranavik from Bangkok, T...
# 2  Bangkok, Thailand  Welcome to Familyroom Apartment.\r\n\r\nA Chic...
# 3  Bangkok, Thailand  from Bangkok but I'm in and out of the city a ...
# 4  Bangkok, Thailand  Full-time legal consultant from Bangkok, Thail...
#
#   host_response_time  ... number_of_reviews_l30d review_scores_rating  \
# 0     within an hour  ...                    0.0                 4.86
# 1     within an hour  ...                    0.0                 4.70
# 2     within an hour  ...                    0.0                 4.70
# 3     within an hour  ...                    0.0                 4.83
# 4     within an hour  ...                    0.0                 5.00
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.95                      4.82                  4.97
# 1                   4.70                      4.70                  4.80
# 2                   4.70                      4.70                  4.80
# 3                   5.00                      4.67                  4.50
# 4                   5.00                      5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.91                   4.66                4.75
# 1                        4.80                   4.60                4.70
# 2                        4.80                   4.60                4.70
# 3                        4.83                   4.83                5.00
# 4                        5.00                   5.00                5.00
#
#   reviews_per_month Precio Venta
# 0              0.43         4.95
# 1              1.00         4.70
# 2              1.00         4.70
# 3              0.06         5.00
# 4              0.01         5.00
#
# [5 rows x 48 columns]

# %%
df = df[df['room_type'] == 'Hotel room']

# %%
df['price'] = df['price'].str.replace('$', '', regex=False)
df['price'] = df['price'].str.replace('.00', '', regex=False)
df['price'] = df['price'].str.replace(',000', '', regex=False)
df['price'] = df['price'].str.replace(',', '.', regex=False)
df['price'] = df['price'].astype(float)
# Out:
# <ipython-input-7-9a1f568ff3ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('$', '', regex=False)
# <ipython-input-7-9a1f568ff3ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('.00', '', regex=False)
# <ipython-input-7-9a1f568ff3ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace(',000', '', regex=False)
# <ipython-input-7-9a1f568ff3ef>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace(',', '.', regex=False)
# <ipython-input-7-9a1f568ff3ef>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='review_scores_cleanliness', x='price',  color = 'blue', data=df)
plt.title('price vs review_scores_cleanliness')
plt.xlabel('price')
plt.ylabel('review_scores_cleanliness')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-8-2a2118cb5fef>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['review_scores_cleanliness']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-80.68814129]]),
#  'rank_': 1,
#  'singular_': array([3.13029451]),
#  'intercept_': array([1705.31850252])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-80.68814129]]
# Intercepto: [1705.31850252]
# y = [-80.68814129]x + [1705.31850252]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.00010359090429534756

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs review_scores_cleanliness')
plt.xlabel('price')
plt.ylabel('review_scores_cleanliness')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['review_scores_cleanliness']])
yPred
# Out:
# array([[1313.98101724],
#        [1310.75349159],
#        [1313.17413583],
#        [1312.36725442],
#        [1317.20854289],
#        [1318.01542431],
#        [1322.04983137],
#        [1317.20854289],
#        [1320.43606855],
#        [1313.17413583],
#        [1301.87779605],
#        [1325.27735702],
#        [1320.43606855],
#        [1335.76681539],
#        [1318.01542431],
#        [1315.59478007],
#        [1315.59478007],
#        [1324.47047561],
#        [1301.87779605],
#        [1331.73240833],
#        [1326.08423844],
#        [1301.87779605],
#        [1318.01542431],
#        [1326.08423844],
#        [1326.08423844],
#        [1309.13972876],
#        [1314.78789866],
#        [1325.27735702],
#        [1313.98101724],
#        [1328.50488268],
#        [1330.92552691],
#        [1301.87779605],
#        [1318.01542431],
#        [1326.08423844],
#        [1315.59478007],
#        [1322.85671278],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1301.87779605],
#        [1318.01542431],
#        [1318.01542431],
#        [1320.43606855],
#        [1317.20854289],
#        [1301.87779605],
#        [1334.15305257],
#        [1326.08423844],
#        [1330.92552691],
#        [1309.94661018],
#        [1323.6635942 ],
#        [1301.87779605],
#        [1342.2218667 ],
#        [1317.20854289],
#        [1325.27735702],
#        [1312.36725442],
#        [1312.36725442],
#        [1301.87779605],
#        [1326.08423844],
#        [1301.87779605],
#        [1301.87779605],
#        [1317.20854289],
#        [1326.08423844],
#        [1334.95993398],
#        [1326.08423844],
#        [1301.87779605],
#        [1301.87779605],
#        [1301.87779605],
#        [1301.87779605],
#        [1301.87779605],
#        [1329.31176409],
#        [1301.87779605],
#        [1330.92552691],
#        [1301.87779605],
#        [1318.01542431],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1342.2218667 ],
#        [1335.76681539],
#        [1315.59478007],
#        [1318.01542431],
#        [1340.60810387],
#        [1326.08423844],
#        [1350.29068082],
#        [1338.18745963],
#        [1326.08423844],
#        [1315.59478007],
#        [1319.62918713],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1301.87779605],
#        [1326.08423844],
#        [1301.87779605],
#        [1301.87779605],
#        [1338.99434104],
#        [1301.87779605],
#        [1301.87779605],
#        [1328.50488268],
#        [1301.87779605],
#        [1301.87779605],
#        [1301.87779605],
#        [1318.01542431],
#        [1301.87779605],
#        [1328.50488268],
#        [1301.87779605],
#        [1318.82230572],
#        [1301.87779605],
#        [1301.87779605],
#        [1313.17413583],
#        [1310.75349159],
#        [1301.87779605],
#        [1301.87779605],
#        [1330.1186455 ],
#        [1309.94661018],
#        [1311.560373  ],
#        [1318.01542431],
#        [1326.08423844],
#        [1315.59478007],
#        [1313.17413583],
#        [1319.62918713],
#        [1317.20854289],
#        [1304.29844029],
#        [1311.560373  ],
#        [1321.24294996],
#        [1308.33284735],
#        [1301.87779605],
#        [1318.01542431],
#        [1301.87779605],
#        [1326.08423844],
#        [1301.87779605],
#        [1301.87779605],
#        [1318.01542431],
#        [1301.87779605],
#        [1314.78789866],
#        [1322.04983137],
#        [1315.59478007],
#        [1310.75349159],
#        [1301.87779605],
#        [1333.34617115],
#        [1318.82230572],
#        [1309.13972876],
#        [1336.5736968 ],
#        [1328.50488268],
#        [1321.24294996],
#        [1332.53928974],
#        [1334.15305257],
#        [1301.87779605],
#        [1318.01542431],
#        [1326.08423844],
#        [1318.01542431],
#        [1307.52596594],
#        [1314.78789866],
#        [1318.01542431],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1319.62918713],
#        [1301.87779605],
#        [1301.87779605],
#        [1332.53928974],
#        [1309.94661018],
#        [1326.08423844],
#        [1335.76681539],
#        [1318.01542431],
#        [1323.6635942 ],
#        [1305.91220311],
#        [1301.87779605],
#        [1301.87779605],
#        [1318.01542431],
#        [1326.08423844],
#        [1326.08423844],
#        [1301.87779605],
#        [1301.87779605],
#        [1326.08423844],
#        [1326.08423844],
#        [

#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1318.01542431],
#        [1326.08423844],
#        [1315.59478007],
#        [1301.87779605],
#        [1313.98101724],
#        [1301.87779605],
#        [1326.08423844],
#        [1339.80122246],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844],
#        [1326.08423844]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#      Unnamed: 0           source  \
# 6             6      city scrape
# 40           40  previous scrape
# 198         198      city scrape
# 329         329      city scrape
# 392         392      city scrape
#
#                                                   name  \
# 6         Comfy bedroom near River pier & BTS  Taksin.
# 40   Luxury Riverview Teakwood Apartment-Great View...
# 198       Baan Nampetch Hostel (Budget Double bedroom)
# 329                      Triple room,Near Grand Palace
# 392   *Kingsize Boutique Room* 10min to Skytrain, WiFi
#
#                                            description  \
# 6    This is one of our 'Escape' sleep room : hoste...
# 40   Attention: right now we are in Europe, so plea...
# 198  Locate in Quiet area within 10 mins walking di...
# 329  Feung Nakorn Balcony : <br />Spacious room wit...
# 392  A very comfortable and cozy place in Sukhumvit...
#
#                                  neighborhood_overview       host_name  \
# 6    Charoen krung street, River pier, Iconsiam, Su...             Tor
# 40   The exact location of the property is:<br /><b...  Maam & Hermann
# 198  We are locate in Payathai Area which comprise ...           Paula
# 329  Feung Nakorn Balcony is the first and only bou...            Sasi
# 392  Easy to get around: Train from Suvarnaphumi Ai...            Alex
#
#      host_since                     host_location  \
# 6    15/10/2010                 Bangkok, Thailand
# 40   12/04/2012                 Bangkok, Thailand
# 198  04/09/2013                 Bangkok, Thailand
# 329  17/04/2014  Krung Thep Maha Nakhon, Thailand
# 392  01/08/2014                 Bangkok, Thailand
#
#                                             host_about  host_response_time  \
# 6    Hello, my name is Tor, Escape at sathorn terra...  within a few hours
# 40   My thai wife Maam and me are living in this fl...      within an hour
# 198  Do the best today and the the best for tomorro...      within an hour
# 329  Hi we are family-run hostel in the middle of R...      within an hour
# 392  I am an authentic and passionate host. I love ...      within an hour
#
#      ... review_scores_rating review_scores_accuracy  \
# 6    ...                 4.80                   4.77
# 40   ...                 4.83                   4.91
# 198  ...                 4.65                   4.70
# 329  ...                 5.00                   4.93
# 392  ...                 4.81                   4.83
#
#     review_scores_cleanliness review_scores_checkin  \
# 6                        4.85                  4.87
# 40                       4.89                  4.82
# 198                      4.86                  4.83
# 329                      4.87                  4.87
# 392                      4.81                  4.94
#
#     review_scores_communication review_scores_location review_scores_value  \
# 6                          4.85                   4.74                4.69
# 40                         4.89                   4.54                4.84
# 198                        4.79                   4.58                4.65
# 329                        4.80                   4.93                4.80
# 392                        4.92                   4.60                4.71
#
#     reviews_per_month Precio Venta Predicciones
# 6                1.27         4.77  1313.981017
# 40               0.80         4.91  1310.753492
# 198              1.18         4.70  1313.174136
# 329              0.13         4.93  1312.367254
# 392              0.33         4.83  1317.208543
#
# [5 rows x 49 columns]

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='review_scores_cleanliness', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('review_scores_cleanliness')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.00010359090429534756

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.010177961696496384
