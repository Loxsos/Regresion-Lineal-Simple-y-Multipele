# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1pkLk2s89-Etn7zIuYV88L_FvDH3sI8qx')
df.head()
# Out:
#    Unnamed: 0           source  \
# 0           0      city scrape
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# ...

# %%
df = df[df['room_type'] == 'Entire home/apt']

# %%
df['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['property_type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15885 entries, 0 to 25078
# Series name: property_type
# Non-Null Count  Dtype
# --------------  -----
# 15885 non-null  object
# dtypes: object(1)
# memory usage: 248.2+ KB

# %%
df['price'] = df['price'].str.replace('$', '', regex=False)

# %%
df['price'] = df['price'].str.replace('.00', '', regex=False)

# %%
df['price'] = df['price'].str.replace(',000', '', regex=False)

# %%
df['price'] = df['price'].str.replace(',', '.', regex=False)

# %%
df['price'] = df['price'].astype(float)

# %%
df['property_type'] = df['property_type'].str.replace('Entire villa','1', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire townhouse','1.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire condo', '2', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire rental unit', '2.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire loft', '3', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire home', '3.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('3.5/apt', '3.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in rental unit', '4', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Room in hostel', '4.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in serviced apartment', '5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in home', '5.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire guesthouse', '6', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire serviced apartment', '6.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in condo', '7', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire cottage', '7.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire chalet', '8', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in hostel', '8.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Room in aparthotel', '9', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire bed and breakfast', '9.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Private room in guesthouse', '10', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Room in boutique hotel', '10.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire bungalow', '11', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Tiny home', '11.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Farm stay', '12', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Dome', '12.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Treehouse', '13', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Room in hotel', '13.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('1/apt', '14', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Entire vacation home', '14.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Casa particular', '15', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Shipping container', '15.5', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Hut', '16', regex=False)

# %%
df['property_type'] = df['property_type'].str.replace('Lighthouse', '16.5', regex=False)

# %%
df['property_type'] = df['property_type'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='property_type', x='price',  color = 'blue', data=df)
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-497-a79b0d0a01aa>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['property_type']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[-3.68460921]]),
#  'rank_': 1,
#  'singular_': array([140.86950488]),
#  'intercept_': array([456.94442932])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[-3.68460921]]
# Intercepto: [456.94442932]
# y = [-3.68460921]x + [456.94442932]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 2.6172793432865937e-05

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['property_type']])
yPred
# Out:
# array([[449.5752109 ],
#        [449.5752109 ],
#        [447.7329063 ],
#        ...,
#        [445.89060169],
#        [445.89060169],
#        [445.89060169]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#     Unnamed: 0           source  \
# 0            0      city scrape
# 8            8      city scrape
# 9            9      city scrape
# 13          13      city scrape
# 14          14  previous scrape
#
#                                               name  \
# 0                  Nice room with superb city view
# 8   Cozy and spacious 1BR with great view, LT rent
# 9              Central Bangkok 3 Bedroom Apartment
# 13  Studio near Chula University/Silom walk to MRT
# 14               Nice and Cozy Room @ Sathorn Area
#
#                                           description  \
# 0   Our cool and comfortable one bedroom apartment...
# 8   The cozy one bed room apartment, conveniently ...
# 9   We are Airbnb Super Hosts. Book our apartment ...
# 13  A centrally located studio apartment with wifi...
# 14  A centrally located studio apartment with wifi...
#
#                                 neighborhood_overview host_name  host_since  \
# ...

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='property_type', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 2.6172793432865937e-05

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.0051159352451791195

# %%
df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)
# Out:
# <ipython-input-511-1e4414937aad>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)

# %%
df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('Half-bath', '.5', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('bath', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('baths', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('s', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('Half-', '.5', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('shared bath', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('shared','', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('private bath', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('private', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('Shared half-', '.5', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('shared baths', '', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.replace('Private half-', '.5', regex=False)

# %%
df['bathrooms_text'] = df['bathrooms_text'].astype(float)

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# <ipython-input-526-1126a6e5cd06>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)

# %%
df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%', '', regex=False)

# %%
df['instant_bookable'] = df['instant_bookable'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# <ipython-input-528-33deb354eca7>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['instant_bookable'] = df['instant_bookable'].replace({'f': 0, 't': 1}).astype(float)

# %%
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)

# %%
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '', regex=False)

# %%
df['host_response_rate'] = df['host_response_rate'].astype(float)

# %%
df['has_availability'] = df['has_availability'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# <ipython-input-532-a5f192c334b4>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['has_availability'] = df['has_availability'].replace({'f': 0, 't': 1}).astype(float)

# %%
df = df[['host_acceptance_rate','host_is_superhost','price','accommodates','bathrooms_text','review_scores_cleanliness','host_identity_verified','instant_bookable','host_total_listings_count','bedrooms','review_scores_value','reviews_per_month','property_type']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15885 entries, 0 to 25078
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_acceptance_rate       15885 non-null  float64
#  1   host_is_superhost          15885 non-null  float64
#  2   price                      15885 non-null  float64
#  3   accommodates               15885 non-null  float64
#  4   bathrooms_text             15885 non-null  float64
#  5   review_scores_cleanliness  15885 non-null  float64
#  6   host_identity_verified     15885 non-null  int64
#  7   instant_bookable           15885 non-null  float64
#  8   host_total_listings_count  15885 non-null  float64
#  9   bedrooms                   15885 non-null  float64
#  10  review_scores_value        15885 non-null  float64
#  11  reviews_per_month          15885 non-null  float64
#  12  property_type              15885 non-null  float64
# ...

# %%
correlacion = df.corr()
correlacion
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.204434  0.019315
# host_is_superhost                      0.204434           1.000000 -0.126904
# price                                  0.019315          -0.126904  1.000000
# accommodates                           0.049610           0.015818 -0.110823
# bathrooms_text                         0.040749           0.005570 -0.081885
# review_scores_cleanliness              0.100425           0.228108 -0.044248
# host_identity_verified                -0.004928           0.150701 -0.483656
# instant_bookable                       0.382086          -0.007772 -0.086470
# host_total_listings_count             -0.008974          -0.041745 -0.152816
# bedrooms                              -0.003485          -0.054156  0.202318
# review_scores_value                    0.087615           0.203646 -0.037275
# ...

# %%
corr = abs(correlacion)
corr
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.204434  0.019315
# host_is_superhost                      0.204434           1.000000  0.126904
# price                                  0.019315           0.126904  1.000000
# accommodates                           0.049610           0.015818  0.110823
# bathrooms_text                         0.040749           0.005570  0.081885
# review_scores_cleanliness              0.100425           0.228108  0.044248
# host_identity_verified                 0.004928           0.150701  0.483656
# instant_bookable                       0.382086           0.007772  0.086470
# host_total_listings_count              0.008974           0.041745  0.152816
# bedrooms                               0.003485           0.054156  0.202318
# review_scores_value                    0.087615           0.203646  0.037275
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black', cbar_kws={'shrink': 0.8}, annot_kws={"size": 10})
plt.title('Matriz de Correlaciones Entire home/apt', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.show()
