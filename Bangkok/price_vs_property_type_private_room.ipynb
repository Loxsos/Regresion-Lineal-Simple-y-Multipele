# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1pkLk2s89-Etn7zIuYV88L_FvDH3sI8qx')
df.head()
# Out:
#    Unnamed: 0           source  \
# 0           0      city scrape
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# ...

# %%
df = df[df['room_type'] == 'Private room']

# %%
df['price'] = df['price'].str.replace('$', '', regex=False)
df['price'] = df['price'].str.replace('.00', '', regex=False)
df['price'] = df['price'].str.replace(',000', '', regex=False)
df['price'] = df['price'].str.replace(',', '.', regex=False)
df['price'] = df['price'].astype(float)
# Out:
# <ipython-input-4-9a1f568ff3ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('$', '', regex=False)
# <ipython-input-4-9a1f568ff3ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.replace('.00', '', regex=False)
# <ipython-input-4-9a1f568ff3ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['property_type'] = df['property_type'].str.replace('Private room in rental unit', '1', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in serviced apartment', '1.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in home', '2', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in condo', '2.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in hostel', '3', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in aparthotel', '3.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in guesthouse', '4', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in hotel', '4.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in townhouse', '5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in loft', '5.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Room in boutique hotel', '6', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in bungalow', '6.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in bed and breakfast', '7', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in villa', '7.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in tiny home', '8', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in cabin', '8.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in earth house', '9', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in nature lodge', '9.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in vacation home', '10', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in floor', '10.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in resort', '11', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in farm stay', '11.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in dome', '12', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in hut', '12.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in houseboat', '13', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in barn', '13.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in casa particular', '14', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in tower', '14.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in shipping container', '15', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in kezhah', '15.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in camper/rv', '16', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in minsu', '16.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in treehouse', '17', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in island', '17.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in guest suite', '18', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in boat', '18.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in earthen home', '19', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in cottage', '19.5', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room in kezhan', '20', regex=False)
df['property_type'] = df['property_type'].str.replace('Private room', '20.5', regex=False)

# %%
df['property_type'] = df['property_type'].astype(float)

# %%
from turtle import color

plt.figure(figsize=(8, 6))
sns.scatterplot(y='property_type', x='price',  color = 'blue', data=df)
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-7-a79b0d0a01aa>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
indep= df[['property_type']]
dep = df[['price']]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(indep, dep)
# Out:
# LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[13.34576585]]),
#  'rank_': 1,
#  'singular_': array([275.70983191]),
#  'intercept_': array([979.79388366])}

# %%
m = model.coef_
b = model.intercept_
print('Pendiente:', m)
print('Intercepto:', b)

# Entonce, el modelo lineal sería:
print(f'y = {m[0]}x + {b}')
# Out:
# Pendiente: [[13.34576585]]
# Intercepto: [979.79388366]
# y = [13.34576585]x + [979.79388366]

# %%
r2 = model.score(indep, dep)
r2
# Out:
# 0.0014443733690285843

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dep, indep, color='blue')
plt.plot(indep, model.predict(indep), color='red')
plt.title('price vs property_type')
plt.xlabel('price')
plt.ylabel('property_type')
plt.grid(True)
plt.show()

# %%
yPred = model.predict(df[['property_type']])
yPred
# Out:
# array([[ 993.13964951],
#        [ 993.13964951],
#        [ 993.13964951],
#        ...,
#        [1013.15829829],
#        [ 993.13964951],
#        [1039.84982999]])

# %%
df['Predicciones'] = yPred
df.head()
# Out:
#    Unnamed: 0           source  \
# 1           1  previous scrape
# 2           2  previous scrape
# 3           3      city scrape
# 4           4      city scrape
# 5           5      city scrape
#
#                                              name  \
# 1                  Easy going landlord,easy place
# 2               modern-style apartment in Bangkok
# 3  Spacious one bedroom at The Kris Condo Bldg. 3
# 4                 Condo with Chaopraya River View
# 5                   Sathorn Terrace Apartment(61)
#
#                                          description  \
# 1  Our cool and comfortable one bedroom apartment...
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
# 5  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview   host_name  host_since  \
# ...

# %%
plt.figure(figsize=(8, 6 ))
sns.scatterplot(x='price', y='property_type', color='blue', data=df, label='Real')
sns.scatterplot(x='price', y='Predicciones', color='red', data=df, label='Predicciones')
#sns.lineplot(x='alcohol', y='Predicciones', color='red', data=df, label='Predicciones')
plt.title('Predictions vs Real')
plt.xlabel('Price')
plt.ylabel('property_type')
plt.legend()
plt.grid(True)
plt.show()

# %%
coefDe = model.score(indep, dep)
coefDe
# Out:
# 0.0014443733690285843

# %%
coefCo = np.sqrt(coefDe)
coefCo
# Out:
# 0.03800491243284984

# %%
df['host_identity_verified'] = df['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' Half-bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' baths', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' Half-', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' Shared half-', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' shared half-', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' shared','', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' private bath', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' private', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' shared baths', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' Private half-', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' hared', '', regex=False)
df['bathrooms_text'] = df['bathrooms_text'].str.replace(' S half-', '', regex=False)
df['bathrooms_text'] = pd.to_numeric(df['bathrooms_text'], errors='coerce')
#df['bathrooms_text'] = df['bathrooms_text'].astype(float)
df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%', '', regex=False)
df['instant_bookable'] = df['instant_bookable'].replace({'f': 0, 't': 1}).astype(float)
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '', regex=False)
df['host_response_rate'] = df['host_response_rate'].astype(float)
df['has_availability'] = df['has_availability'].replace({'f': 0, 't': 1}).astype(float)
# Out:
# <ipython-input-23-a46314adb5de>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['host_is_superhost'] = df['host_is_superhost'].replace({'f': 0, 't': 1}).astype(float)
# <ipython-input-23-a46314adb5de>:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['instant_bookable'] = df['instant_bookable'].replace({'f': 0, 't': 1}).astype(float)
# ...

# %%
df = df[['host_acceptance_rate','host_is_superhost','price','accommodates','bathrooms_text','review_scores_cleanliness','host_identity_verified','instant_bookable','host_total_listings_count','bedrooms','review_scores_value','reviews_per_month','property_type']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8195 entries, 1 to 25069
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_acceptance_rate       8195 non-null   float64
#  1   host_is_superhost          8195 non-null   float64
#  2   price                      8195 non-null   float64
#  3   accommodates               8195 non-null   float64
#  4   bathrooms_text             7063 non-null   float64
#  5   review_scores_cleanliness  8195 non-null   float64
#  6   host_identity_verified     8195 non-null   int64
#  7   instant_bookable           8195 non-null   float64
#  8   host_total_listings_count  8195 non-null   float64
#  9   bedrooms                   8195 non-null   float64
#  10  review_scores_value        8195 non-null   float64
#  11  reviews_per_month          8195 non-null   float64
#  12  property_type              8195 non-null   float64
# ...

# %%
correlacion = df.corr()
correlacion
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.200507 -0.069425
# host_is_superhost                      0.200507           1.000000 -0.226644
# price                                 -0.069425          -0.226644  1.000000
# accommodates                           0.075234           0.067204 -0.032486
# bathrooms_text                         0.012726          -0.018973  0.020530
# review_scores_cleanliness              0.110846           0.258889 -0.134215
# host_identity_verified                -0.023200           0.198869 -0.580789
# instant_bookable                       0.274544           0.108927 -0.212042
# host_total_listings_count             -0.073575          -0.007898 -0.100452
# bedrooms                               0.037234          -0.138311  0.482797
# review_scores_value                    0.121666           0.259540 -0.136606
# ...

# %%
corr = abs(correlacion)
corr
# Out:
#                            host_acceptance_rate  host_is_superhost     price  \
# host_acceptance_rate                   1.000000           0.200507  0.069425
# host_is_superhost                      0.200507           1.000000  0.226644
# price                                  0.069425           0.226644  1.000000
# accommodates                           0.075234           0.067204  0.032486
# bathrooms_text                         0.012726           0.018973  0.020530
# review_scores_cleanliness              0.110846           0.258889  0.134215
# host_identity_verified                 0.023200           0.198869  0.580789
# instant_bookable                       0.274544           0.108927  0.212042
# host_total_listings_count              0.073575           0.007898  0.100452
# bedrooms                               0.037234           0.138311  0.482797
# review_scores_value                    0.121666           0.259540  0.136606
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black', cbar_kws={'shrink': 0.8}, annot_kws={"size": 10})
plt.title('Matriz de Correlaciones Private Room', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.show()
